# %% [markdown]
# <a href="https://colab.research.google.com/github/nawnie/faceswap/blob/master/EveryDream_Tools.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title #Connect to Google Drive
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # Please read the documentation here before you start.
#
# I suggest reading this doc before you connect to your runtime to avoid using credits or being charged while you figure it out.
#
# [Auto Captioning Readme](doc/AUTO_CAPTION.md)
#
# This notebook requires an Nvidia GPU instance. Any will do, you don't need anything power.  As low as 4GB should be fine.
#
# Only colab has automatic file transfers at this time.  If you are using another platform, you will need to manually download your output files.

# %%
#download repo
# !git clone https://github.com/victorchall/EveryDream.git
# Set working directory
# %cd EveryDream

# %%
# install requirements
# !pip install torch=='1.12.1+cu113' 'torchvision==0.13.1+cu113' --extra-index-url https://download.pytorch.org/whl/cu113
# !pip install pandas>='1.3.5'
# !git clone https://github.com/salesforce/BLIP scripts/BLIP
# !pip install timm
# !pip install fairscale=='0.4.4'
# !pip install transformers=='4.19.2'
# !pip install timm
# !pip install aiofiles
# !pip install colorama

# %% [markdown]
# #Extract Frames from video
#
# Here we will use the folder input_vid and upload in the same way we did our images

# %%
# !python /scripts/extract_video_frames.py \
--vid_dir input_vid \
--out_dir output/vid \
--format png \
--interval 10

# %% [markdown]
# Move the extracted frames to the input directory for captions

# %%
# !cp -r output/vid input

# %% [markdown]
# # Upload your input images into the EveryDream/input folder
#
# ![upload to input](https://github.com/victorchall/EveryDream/blob/main/demo/upload_images_caption.png?raw=1)

# %% [markdown]
# ## Please read the documentation for information on the parameters
#
# [Auto Captioning](doc/AUTO_CAPTION.md)
#
# *You cannot have commented lines between uncommented lines.  If you uncomment a line below, move it above any other commented lines.*
#
# *!python must remain the first line.*
#
# Default params should work fairly well.

# %%
# !python scripts/auto_caption.py \
--img_dir input \
--out_dir output \
--min_length 34 \
#--q_factor 1.3 \
#--nucleus \

## mutiple files can be targeted in succession

#!python scripts/auto_caption.py \
#--img_dir input/subfolder \
#--out_dir output/subfolder \
#--format mrwho \
#--min_length 34 \
#--q_factor 1.3 \
#--nucleus \

name = "kori page"

# !python scripts/filename_replace.py \
--img_dir output \
--find "woman" \
--replace "$name"

# !python scripts/filename_replace.py \
--img_dir output \
--find "person" \
--replace "$name"

# !python scripts/filename_replace.py \
--img_dir output \
--find "girl" \
--replace "$name"

# !python scripts/filename_replace.py \
--img_dir output \
--find "a $name" \
--replace "$name"
# Out:
# Unix detected, using default asyncio event loop policy
# starting
# input_dir:  input
# Model already cached to: .cache/model_base_caption_capfilt_large.pth
# load checkpoint from .cache/model_base_caption_capfilt_large.pth
# loading model to cuda
# working image:  input/Kori Paige_(7).png
# 2023-04-12 02:33:38.731828: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-12 02:33:39.686792: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# working image:  input/Kori Paige_(22).png
# working image:  input/Kori Paige_(45).png
# working image:  input/Kori Paige_(2).png
# working image:  input/Kori Paige_(1).png
# working image:  input/Kori Paige_(21).png
# working image:  input/Kori Paige_(1).jpg
# working image:  input/Kori Paige_(17).png
# working image:  input/Kori Paige_(40).png
# working image:  input/Kori Paige_(14).png
# working image:  input/Kori Paige_(34).png
# working image:  input/Kori Paige_(10).png
# working image:  input/Kori Paige_(25).png
# working image:  input/Kori Paige_(8).png
# working image:  input/Kori Paige_(23).png
# working image:  input/Kori Paige_(18).png
# working image:  input/Kori Paige_(31).png
# working image:  input/Kori Paige_(12).png
# working image:  input/Kori Paige_(27).png
# working image:  input/Kori Paige_(28).png
# working image:  input/Kori Paige_(20).png
# working image:  input/Kori Paige_(43).png
# working image:  input/Kori Paige_(9).png
# working image:  input/Kori Paige_(3).png
# working image:  input/Kori Paige_(39).png
# working image:  input/Kori Paige_(4).png
# working image:  input/Kori Paige_(13).png
# working image:  input/Kori Paige_(5).png
# working image:  input/Kori Paige_(48).png
# working image:  input/Kori Paige_(33).png
# working image:  input/Kori Paige_(44).png
# working image:  input/Kori Paige_(47).png
# working image:  input/Kori Paige_(15).png
# working image:  input/Kori Paige_(42).png
# working image:  input/Kori Paige_(16).png
# working image:  input/Kori Paige_(19).png
# working image:  input/Kori Paige_(36).png
# working image:  input/Kori Paige_(29).png
# working image:  input/Kori Paige_(38).png
# working image:  input/Kori Paige_(46).png
# working image:  input/Kori Paige_(35).png
# working image:  input/Kori Paige_(41).png
# working image:  input/Kori Paige_(24).png
# working image:  input/Kori Paige_(37).png
# working image:  input/Kori Paige_(26).png
# working image:  input/Kori Paige_(11).png
# working image:  input/Kori Paige_(6).png
# working image:  input/Kori Paige_(32).png
# working image:  input/Kori Paige_(30).png
# output/a close up of a person with pink and blue hair with snow on her face and a street sign in the background with trees and snow on the ground_20.png
# Renaming output/a close up of a person with pink and blue hair with snow on her face and a street sign in the background with trees and snow on the ground_20.png to output/a close up of a person with pink and blue hair with snow on her face and a street sign in the background with trees and snow on the ground_20.png
# filename already exists, appended '_n' to output/a close up of a person with pink and blue hair with snow on her face and a street sign in the background with trees and snow on the ground_20 _0.png
# output/a woman with pink hair in a black bikini standing in the water under a pier with her hands in the air and her right hand up in the air_31.png
# Renaming output/a woman with pink hair in a black bikini standing in the water under a pier with her hands in the air and her right hand up in the air_31.png to output/a kori page with pink hair in a black bikini standing in the water under a pier with her hands in the air and her right hand up in the air_31.png
# output/a girl with blue and purple hair standing next to a girl with pink and blue hair and a girl with blue and purple hair standing next to each other_22.png
# Renaming output/a girl with blue and purple hair standing next to a girl with pink and blue hair and a girl with blue and purple hair standing next to each other_22.png to output/a girl with blue and purple hair standing next to a girl with pink and blue hair and a girl with blue and purple hair standing next to each other_22.png
# filename already exists, appended '_n' to output/a girl with blue and purple hair standing next to a girl with pink and blue hair and a girl with blue and purple hair standing next to each other_22 _2.png
# output/a woman holding a fish in her hands while standing next to a body of water with trees on both sides of her face and a body of water behind her_45.png
# Renaming output/a woman holding a fish in her hands while standing next to a body of water with trees on both sides of her face and a body of water behind her_45.png to output/a kori page holding a fish in her hands while standing next to a body of water with trees on both sides of her face and a body of water behind her_45.png
# output/a woman standing in front of a mountain with a cell phone in her hand and a cell phone in her other hand, with a mountain in the background_18.png
# Renaming output/a woman standing in front of a mountain with a cell phone in her hand and a cell phone in her other hand, with a mountain in the background_18.png to output/a kori page standing in front of a mountain with a cell phone in her hand and a cell phone in her other hand, with a mountain in the background_18.png
# output/a woman with pink hair standing on a dirt path next to a body of water with a bottle of water in her hand and a cup in her other hand_23.png
# Renaming output/a woman with pink hair standing on a dirt path next to a body of water with a bottle of water in her hand and a cup in her other hand_23.png to output/a kori page with pink hair standing on a dirt path next to a body of water with a bottle of water in her hand and a cup in her other hand_23.png
# output/two girls standing next to each other in front of a building with a clock on the side of the building and people sitting at tables on the other side of the street_32.png
# Renaming output/two girls standing next to each other in front of a building with a clock on the side of the building and people sitting at tables on the other side of the street_32.png to output/two girls standing next to each other in front of a building with a clock on the side of the building and people sitting at tables on the other side of the street_32.png
# filename already exists, appended '_n' to output/two girls standing next to each other in front of a building with a clock on the side of the building and people sitting at tables on the other side of the street_32 _6.png
# output/a close up of a person with dreadlocks on her head and a tattoo on her upper half of the body and behind her is a blue tank top_16.png
# Renaming output/a close up of a person with dreadlocks on her head and a tattoo on her upper half of the body and behind her is a blue tank top_16.png to output/a close up of a person with dreadlocks on her head and a tattoo on her upper half of the body and behind her is a blue tank top_16.png
# filename already exists, appended '_n' to output/a close up of a person with dreadlocks on her head and a tattoo on her upper half of the body and behind her is a blue tank top_16 _7.png
# output/a woman with dreadlocks taking a selfie in front of a mountain with a pine tree in the foreground and a blue sky with clouds in the background_37.png
# Renaming output/a woman with dreadlocks taking a selfie in front of a mountain with a pine tree in the foreground and a blue sky with clouds in the background_37.png to output/a kori page with dreadlocks taking a selfie in front of a mountain with a pine tree in the foreground and a blue sky with clouds in the background_37.png
# output/a girl with pink hair sitting in the back seat of a car with pink hair and piercings on her nose and behind the wheel of a car seat_3.png
# Renaming output/a girl with pink hair sitting in the back seat of a car with pink hair and piercings on her nose and behind the wheel of a car seat_3.png to output/a girl with pink hair sitting in the back seat of a car with pink hair and piercings on her nose and behind the wheel of a car seat_3.png
# filename already exists, appended '_n' to output/a girl with pink hair sitting in the back seat of a car with pink hair and piercings on her nose and behind the wheel of a car seat_3 _9.png
# output/a woman in a bikini standing next to a wooden fence in front of a body of water with trees and bushes on both sides of the fence is posing for a picture_24.png
# Renaming output/a woman in a bikini standing next to a wooden fence in front of a body of water with trees and bushes on both sides of the fence is posing for a picture_24.png to output/a kori page in a bikini standing next to a wooden fence in front of a body of water with trees and bushes on both sides of the fence is posing for a picture_24.png
# output/a woman in a red swimsuit with tattoos on her chest and chest, standing in a living room with a ceiling fan and a staircase in the background_14.png
# Renaming output/a woman in a red swimsuit with tattoos on her chest and chest, standing in a living room with a ceiling fan and a staircase in the background_14.png to output/a kori page in a red swimsuit with tattoos on her chest and chest, standing in a living room with a ceiling fan and a staircase in the background_14.png
# output/a young woman with dreadlocks standing in front of a lush green forest, smiling at the camera, wearing a blue jacket and white t - shirt_44.png
# Renaming output/a young woman with dreadlocks standing in front of a lush green forest, smiling at the camera, wearing a blue jacket and white t - shirt_44.png to output/a young kori page with dreadlocks standing in front of a lush green forest, smiling at the camera, wearing a blue jacket and white t - shirt_44.png
# output/a girl with pink hair is sitting on the ground with her legs crossed and a smile on her face as she sits in a field with mountains in the background_17.png
# Renaming output/a girl with pink hair is sitting on the ground with her legs crossed and a smile on her face as she sits in a field with mountains in the background_17.png to output/a girl with pink hair is sitting on the ground with her legs crossed and a smile on her face as she sits in a field with mountains in the background_17.png
# filename already exists, appended '_n' to output/a girl with pink hair is sitting on the ground with her legs crossed and a smile on her face as she sits in a field with mountains in the background_17 _13.png
# output/a woman in a bikini standing next to a body of water with an inflatable raft in the foreground and a body of water in the background_29.png
# Renaming output/a woman in a bikini standing next to a body of water with an inflatable raft in the foreground and a body of water in the background_29.png to output/a kori page in a bikini standing next to a body of water with an inflatable raft in the foreground and a body of water in the background_29.png
# output/a girl with pink hair standing in front of a field of sunflowers and smiling at the camera with her long pink hair in front of her face_9.png
# Renaming output/a girl with pink hair standing in front of a field of sunflowers and smiling at the camera with her long pink hair in front of her face_9.png to output/a girl with pink hair standing in front of a field of sunflowers and smiling at the camera with her long pink hair in front of her face_9.png
# filename already exists, appended '_n' to output/a girl with pink hair standing in front of a field of sunflowers and smiling at the camera with her long pink hair in front of her face_9 _15.png
# output/a woman with blue hair sitting on a chair with tattoos on her legs and a tattoo on her lower half of the leg of the woman's leg_21.png
# Renaming output/a woman with blue hair sitting on a chair with tattoos on her legs and a tattoo on her lower half of the leg of the woman's leg_21.png to output/a kori page with blue hair sitting on a chair with tattoos on her legs and a tattoo on her lower half of the leg of the kori page's leg_21.png
# output/a woman standing on a beach with a palm tree in the foreground and a cloudy sky in the background, with a palm tree in the foreground_6.jpg
# Renaming output/a woman standing on a beach with a palm tree in the foreground and a cloudy sky in the background, with a palm tree in the foreground_6.jpg to output/a kori page standing on a beach with a palm tree in the foreground and a cloudy sky in the background, with a palm tree in the foreground_6.jpg
# output/a woman sitting in the back seat of a car with a cell phone in her hand and a cell phone in her other hand as well as well as she smiles_5.png
# Renaming output/a woman sitting in the back seat of a car with a cell phone in her hand and a cell phone in her other hand as well as well as she smiles_5.png to output/a kori page sitting in the back seat of a car with a cell phone in her hand and a cell phone in her other hand as well as well as she smiles_5.png
# output/a young woman with blue dreadlocks and piercings sitting on a porch with her hand on her hip and looking at the camera with a smile on her face_36.png
# Renaming output/a young woman with blue dreadlocks and piercings sitting on a porch with her hand on her hip and looking at the camera with a smile on her face_36.png to output/a young kori page with blue dreadlocks and piercings sitting on a porch with her hand on her hip and looking at the camera with a smile on her face_36.png
# output/a girl with pink hair wearing a white graduation cap and gown with a tassel and a tassel hanging off of it's side of her head_34.png
# Renaming output/a girl with pink hair wearing a white graduation cap and gown with a tassel and a tassel hanging off of it's side of her head_34.png to output/a girl with pink hair wearing a white graduation cap and gown with a tassel and a tassel hanging off of it's side of her head_34.png
# filename already exists, appended '_n' to output/a girl with pink hair wearing a white graduation cap and gown with a tassel and a tassel hanging off of it's side of her head_34 _20.png
# output/two young women sitting next to each other in front of a sign that says love is in the air and a heart is on the top of the sign_7.png
# Renaming output/two young women sitting next to each other in front of a sign that says love is in the air and a heart is on the top of the sign_7.png to output/two young women sitting next to each other in front of a sign that says love is in the air and a heart is on the top of the sign_7.png
# filename already exists, appended '_n' to output/two young women sitting next to each other in front of a sign that says love is in the air and a heart is on the top of the sign_7 _21.png
# output/a woman sitting on the ground next to a baby in a stroller with a pacifier in her mouth and a baby in a stroller behind her_8.png
# Renaming output/a woman sitting on the ground next to a baby in a stroller with a pacifier in her mouth and a baby in a stroller behind her_8.png to output/a kori page sitting on the ground next to a baby in a stroller with a pacifier in her mouth and a baby in a stroller behind her_8.png
# output/a woman in a bikini standing next to a fence and looking at a body of water that has blue and green algae growing on the bottom of the water_38.png
# Renaming output/a woman in a bikini standing next to a fence and looking at a body of water that has blue and green algae growing on the bottom of the water_38.png to output/a kori page in a bikini standing next to a fence and looking at a body of water that has blue and green algae growing on the bottom of the water_38.png
# output/a woman standing in front of a bed wearing ripped jeans and a t - shirt with an image of a cat on the front of the t - shirt_13.png
# Renaming output/a woman standing in front of a bed wearing ripped jeans and a t - shirt with an image of a cat on the front of the t - shirt_13.png to output/a kori page standing in front of a bed wearing ripped jeans and a t - shirt with an image of a cat on the front of the t - shirt_13.png
# output/a woman in a tie - dyed shirt and fishnet stockings poses for a picture in front of a painting of a woman wearing fishnet stockings and fishnet stockings_2.png
# Renaming output/a woman in a tie - dyed shirt and fishnet stockings poses for a picture in front of a painting of a woman wearing fishnet stockings and fishnet stockings_2.png to output/a kori page in a tie - dyed shirt and fishnet stockings poses for a picture in front of a painting of a kori page wearing fishnet stockings and fishnet stockings_2.png
# output/a collage of photos of a woman, a child, and a woman sitting on a bench in front of a red truck with a sunset in the background_30.png
# Renaming output/a collage of photos of a woman, a child, and a woman sitting on a bench in front of a red truck with a sunset in the background_30.png to output/a collage of photos of a kori page, a child, and a kori page sitting on a bench in front of a red truck with a sunset in the background_30.png
# output/a woman standing on top of a large rock in the middle of a forest on top of a large rock in the foreground is a fence and trees in the background_46.png
# Renaming output/a woman standing on top of a large rock in the middle of a forest on top of a large rock in the foreground is a fence and trees in the background_46.png to output/a kori page standing on top of a large rock in the middle of a forest on top of a large rock in the foreground is a fence and trees in the background_46.png
# output/a woman covered in mud posing for a picture in a wooded area with trees and bushes behind her, with a pink mohawk on her head and a gray tank top_25.png
# Renaming output/a woman covered in mud posing for a picture in a wooded area with trees and bushes behind her, with a pink mohawk on her head and a gray tank top_25.png to output/a kori page covered in mud posing for a picture in a wooded area with trees and bushes behind her, with a pink mohawk on her head and a gray tank top_25.png
# output/a girl with pink hair is posing for a picture in a wooded area with leaves on the ground and a lot of trees with yellow and orange leaves on the ground_26.png
# Renaming output/a girl with pink hair is posing for a picture in a wooded area with leaves on the ground and a lot of trees with yellow and orange leaves on the ground_26.png to output/a girl with pink hair is posing for a picture in a wooded area with leaves on the ground and a lot of trees with yellow and orange leaves on the ground_26.png
# filename already exists, appended '_n' to output/a girl with pink hair is posing for a picture in a wooded area with leaves on the ground and a lot of trees with yellow and orange leaves on the ground_26 _29.png
# output/a close up of a person with pink hair wearing a black tank top and a bracelet with a bird on it and a flower on the side of her arm_28.png
# Renaming output/a close up of a person with pink hair wearing a black tank top and a bracelet with a bird on it and a flower on the side of her arm_28.png to output/a close up of a person with pink hair wearing a black tank top and a bracelet with a bird on it and a flower on the side of her arm_28.png
# filename already exists, appended '_n' to output/a close up of a person with pink hair wearing a black tank top and a bracelet with a bird on it and a flower on the side of her arm_28 _30.png
# output/a woman with pink hair and a black shirt is standing in front of a tree and a man with pink hair is wearing a black shirt and a black t - shirt_15.png
# Renaming output/a woman with pink hair and a black shirt is standing in front of a tree and a man with pink hair is wearing a black shirt and a black t - shirt_15.png to output/a kori page with pink hair and a black shirt is standing in front of a tree and a man with pink hair is wearing a black shirt and a black t - shirt_15.png
# output/a woman standing in front of a body of water wearing a white tank top and ripped jeans with a tattoo on her arm and a chain around her neck_48.png
# Renaming output/a woman standing in front of a body of water wearing a white tank top and ripped jeans with a tattoo on her arm and a chain around her neck_48.png to output/a kori page standing in front of a body of water wearing a white tank top and ripped jeans with a tattoo on her arm and a chain around her neck_48.png
# output/a woman in ripped jeans and a yellow beanie poses for a picture in a grassy field with a mountain in the backgrouund of the background_19.png
# Renaming output/a woman in ripped jeans and a yellow beanie poses for a picture in a grassy field with a mountain in the backgrouund of the background_19.png to output/a kori page in ripped jeans and a yellow beanie poses for a picture in a grassy field with a mountain in the backgrouund of the background_19.png
# output/a woman sitting next to a small child on a bench in front of a train with the words happy birthday written on the back of the woman's shirt_11.png
# Renaming output/a woman sitting next to a small child on a bench in front of a train with the words happy birthday written on the back of the woman's shirt_11.png to output/a kori page sitting next to a small child on a bench in front of a train with the words happy birthday written on the back of the kori page's shirt_11.png
# output/a woman with red hair standing in front of a bridge with a camera in her hand and holding a camera in one hand and a camera in the other hand_0.png
# Renaming output/a woman with red hair standing in front of a bridge with a camera in her hand and holding a camera in one hand and a camera in the other hand_0.png to output/a kori page with red hair standing in front of a bridge with a camera in her hand and holding a camera in one hand and a camera in the other hand_0.png
# output/a close up of a person with pink hair holding a camera and wearing a purple tank top and holding a camera in one hand and a pink frisbee in the other hand_39.png
# Renaming output/a close up of a person with pink hair holding a camera and wearing a purple tank top and holding a camera in one hand and a pink frisbee in the other hand_39.png to output/a close up of a person with pink hair holding a camera and wearing a purple tank top and holding a camera in one hand and a pink frisbee in the other hand_39.png
# filename already exists, appended '_n' to output/a close up of a person with pink hair holding a camera and wearing a purple tank top and holding a camera in one hand and a pink frisbee in the other hand_39 _36.png
# output/a girl with pink dreadlocks and a beanie smiles at the camera while standing in front of a skate park with a skateboard in the background_27.png
# Renaming output/a girl with pink dreadlocks and a beanie smiles at the camera while standing in front of a skate park with a skateboard in the background_27.png to output/a girl with pink dreadlocks and a beanie smiles at the camera while standing in front of a skate park with a skateboard in the background_27.png
# filename already exists, appended '_n' to output/a girl with pink dreadlocks and a beanie smiles at the camera while standing in front of a skate park with a skateboard in the background_27 _37.png
# output/a woman in a bikini standing on the beach with a camera in her hand and a camera in her other hand, in front of a body of water with a pier in the background_43.png
# Renaming output/a woman in a bikini standing on the beach with a camera in her hand and a camera in her other hand, in front of a body of water with a pier in the background_43.png to output/a kori page in a bikini standing on the beach with a camera in her hand and a camera in her other hand, in front of a body of water with a pier in the background_43.png
# output/a woman in a red dress with a tattoo on her left arm and a tattoo on her right arm and a tattoo on her left arm and her left arm_1.png
# Renaming output/a woman in a red dress with a tattoo on her left arm and a tattoo on her right arm and a tattoo on her left arm and her left arm_1.png to output/a kori page in a red dress with a tattoo on her left arm and a tattoo on her right arm and a tattoo on her left arm and her left arm_1.png
# output/a woman with purple hair standing in front of a mirror making a peace sign with her right hand and a cat on her left side of her left hand_41.png
# Renaming output/a woman with purple hair standing in front of a mirror making a peace sign with her right hand and a cat on her left side of her left hand_41.png to output/a kori page with purple hair standing in front of a mirror making a peace sign with her right hand and a cat on her left side of her left hand_41.png
# output/a woman standing in front of a red door with her hand on the side of the door and her hand on the side of the door of the door_35.png
# Renaming output/a woman standing in front of a red door with her hand on the side of the door and her hand on the side of the door of the door_35.png to output/a kori page standing in front of a red door with her hand on the side of the door and her hand on the side of the door of the door_35.png
# output/a woman with pink hair standing on the side of a train with her hand up to the side of the train as she stands on the side of the train_47.png
# Renaming output/a woman with pink hair standing on the side of a train with her hand up to the side of the train as she stands on the side of the train_47.png to output/a kori page with pink hair standing on the side of a train with her hand up to the side of the train as she stands on the side of the train_47.png
# output/a girl in a green shirt and a yellow hat is playing with a frisbee in the grass near a body of water with trees in the background_12.png
# Renaming output/a girl in a green shirt and a yellow hat is playing with a frisbee in the grass near a body of water with trees in the background_12.png to output/a girl in a green shirt and a yellow hat is playing with a frisbee in the grass near a body of water with trees in the background_12.png
# filename already exists, appended '_n' to output/a girl in a green shirt and a yellow hat is playing with a frisbee in the grass near a body of water with trees in the background_12 _43.png
# output/a woman in a red bikini standing in a room with a tattoo on her right arm and a tattoo on her left arm, and a tattoo on her left arm_42.png
# Renaming output/a woman in a red bikini standing in a room with a tattoo on her right arm and a tattoo on her left arm, and a tattoo on her left arm_42.png to output/a kori page in a red bikini standing in a room with a tattoo on her right arm and a tattoo on her left arm, and a tattoo on her left arm_42.png
# output/a woman in a blue bikini standing next to a body of water with a frisbee in her hand and a frisbee in her other hand_10.png
# Renaming output/a woman in a blue bikini standing next to a body of water with a frisbee in her hand and a frisbee in her other hand_10.png to output/a kori page in a blue bikini standing next to a body of water with a frisbee in her hand and a frisbee in her other hand_10.png
# output/a woman with a tattoo on her arm holding a wine bottle and a wine bottle in one hand and a wine bottle in the other hand and a wine bottle in the other hand_4.png
# Renaming output/a woman with a tattoo on her arm holding a wine bottle and a wine bottle in one hand and a wine bottle in the other hand and a wine bottle in the other hand_4.png to output/a kori page with a tattoo on her arm holding a wine bottle and a wine bottle in one hand and a wine bottle in the other hand and a wine bottle in the other hand_4.png
# output/a woman with blue hair and piercings standing in front of a door with a smile on her face and wearing a red tank top with a black band around her neck_33.png
# Renaming output/a woman with blue hair and piercings standing in front of a door with a smile on her face and wearing a red tank top with a black band around her neck_33.png to output/a kori page with blue hair and piercings standing in front of a door with a smile on her face and wearing a red tank top with a black band around her neck_33.png
# output/a young woman sitting on the ground with her hand under her chin, wearing a yellow beanie and a blue t - shirt with red and black shorts_40.png
# Renaming output/a young woman sitting on the ground with her hand under her chin, wearing a yellow beanie and a blue t - shirt with red and black shorts_40.png to output/a young kori page sitting on the ground with her hand under her chin, wearing a yellow beanie and a blue t - shirt with red and black shorts_40.png
# /content/EveryDream/scripts/filename_replace.py executed in 0.06 seconds.
# output/a kori page in a blue bikini standing next to a body of water with a frisbee in her hand and a frisbee in her other hand_10.png
# Renaming output/a kori page in a blue bikini standing next to a body of water with a frisbee in her hand and a frisbee in her other hand_10.png to output/a kori page in a blue bikini standing next to a body of water with a frisbee in her hand and a frisbee in her other hand_10.png
# filename already exists, appended '_n' to output/a kori page in a blue bikini standing next to a body of water with a frisbee in her hand and a frisbee in her other hand_10 _0.png
# output/a kori page standing on top of a large rock in the middle of a forest on top of a large rock in the foreground is a fence and trees in the background_46.png
# Renaming output/a kori page standing on top of a large rock in the middle of a forest on top of a large rock in the foreground is a fence and trees in the background_46.png to output/a kori page standing on top of a large rock in the middle of a forest on top of a large rock in the foreground is a fence and trees in the background_46.png
# filename already exists, appended '_n' to output/a kori page standing on top of a large rock in the middle of a forest on top of a large rock in the foreground is a fence and trees in the background_46 _1.png
# output/a close up of a person with pink hair wearing a black tank top and a bracelet with a bird on it and a flower on the side of her arm_28 _30.png
# Renaming output/a close up of a person with pink hair wearing a black tank top and a bracelet with a bird on it and a flower on the side of her arm_28 _30.png to output/a close up of a kori page with pink hair wearing a black tank top and a bracelet with a bird on it and a flower on the side of her arm_28 _30.png
# output/a kori page sitting on the ground next to a baby in a stroller with a pacifier in her mouth and a baby in a stroller behind her_8.png
# Renaming output/a kori page sitting on the ground next to a baby in a stroller with a pacifier in her mouth and a baby in a stroller behind her_8.png to output/a kori page sitting on the ground next to a baby in a stroller with a pacifier in her mouth and a baby in a stroller behind her_8.png
# filename already exists, appended '_n' to output/a kori page sitting on the ground next to a baby in a stroller with a pacifier in her mouth and a baby in a stroller behind her_8 _3.png
# output/a kori page with pink hair standing on the side of a train with her hand up to the side of the train as she stands on the side of the train_47.png
# Renaming output/a kori page with pink hair standing on the side of a train with her hand up to the side of the train as she stands on the side of the train_47.png to output/a kori page with pink hair standing on the side of a train with her hand up to the side of the train as she stands on the side of the train_47.png
# filename already exists, appended '_n' to output/a kori page with pink hair standing on the side of a train with her hand up to the side of the train as she stands on the side of the train_47 _4.png
# output/a girl with pink dreadlocks and a beanie smiles at the camera while standing in front of a skate park with a skateboard in the background_27 _37.png
# Renaming output/a girl with pink dreadlocks and a beanie smiles at the camera while standing in front of a skate park with a skateboard in the background_27 _37.png to output/a girl with pink dreadlocks and a beanie smiles at the camera while standing in front of a skate park with a skateboard in the background_27 _37.png
# filename already exists, appended '_n' to output/a girl with pink dreadlocks and a beanie smiles at the camera while standing in front of a skate park with a skateboard in the background_27 _37 _5.png
# output/a kori page standing in front of a red door with her hand on the side of the door and her hand on the side of the door of the door_35.png
# Renaming output/a kori page standing in front of a red door with her hand on the side of the door and her hand on the side of the door of the door_35.png to output/a kori page standing in front of a red door with her hand on the side of the door and her hand on the side of the door of the door_35.png
# filename already exists, appended '_n' to output/a kori page standing in front of a red door with her hand on the side of the door and her hand on the side of the door of the door_35 _6.png
# output/a kori page sitting next to a small child on a bench in front of a train with the words happy birthday written on the back of the kori page's shirt_11.png
# Renaming output/a kori page sitting next to a small child on a bench in front of a train with the words happy birthday written on the back of the kori page's shirt_11.png to output/a kori page sitting next to a small child on a bench in front of a train with the words happy birthday written on the back of the kori page's shirt_11.png
# filename already exists, appended '_n' to output/a kori page sitting next to a small child on a bench in front of a train with the words happy birthday written on the back of the kori page's shirt_11 _7.png
# output/a kori page covered in mud posing for a picture in a wooded area with trees and bushes behind her, with a pink mohawk on her head and a gray tank top_25.png
# Renaming output/a kori page covered in mud posing for a picture in a wooded area with trees and bushes behind her, with a pink mohawk on her head and a gray tank top_25.png to output/a kori page covered in mud posing for a picture in a wooded area with trees and bushes behind her, with a pink mohawk on her head and a gray tank top_25.png
# filename already exists, appended '_n' to output/a kori page covered in mud posing for a picture in a wooded area with trees and bushes behind her, with a pink mohawk on her head and a gray tank top_25 _8.png
# output/a kori page standing in front of a bed wearing ripped jeans and a t - shirt with an image of a cat on the front of the t - shirt_13.png
# Renaming output/a kori page standing in front of a bed wearing ripped jeans and a t - shirt with an image of a cat on the front of the t - shirt_13.png to output/a kori page standing in front of a bed wearing ripped jeans and a t - shirt with an image of a cat on the front of the t - shirt_13.png
# filename already exists, appended '_n' to output/a kori page standing in front of a bed wearing ripped jeans and a t - shirt with an image of a cat on the front of the t - shirt_13 _9.png
# output/a kori page with pink hair in a black bikini standing in the water under a pier with her hands in the air and her right hand up in the air_31.png
# Renaming output/a kori page with pink hair in a black bikini standing in the water under a pier with her hands in the air and her right hand up in the air_31.png to output/a kori page with pink hair in a black bikini standing in the water under a pier with her hands in the air and her right hand up in the air_31.png
# filename already exists, appended '_n' to output/a kori page with pink hair in a black bikini standing in the water under a pier with her hands in the air and her right hand up in the air_31 _10.png
# output/a kori page with a tattoo on her arm holding a wine bottle and a wine bottle in one hand and a wine bottle in the other hand and a wine bottle in the other hand_4.png
# Renaming output/a kori page with a tattoo on her arm holding a wine bottle and a wine bottle in one hand and a wine bottle in the other hand and a wine bottle in the other hand_4.png to output/a kori page with a tattoo on her arm holding a wine bottle and a wine bottle in one hand and a wine bottle in the other hand and a wine bottle in the other hand_4.png
# filename already exists, appended '_n' to output/a kori page with a tattoo on her arm holding a wine bottle and a wine bottle in one hand and a wine bottle in the other hand and a wine bottle in the other hand_4 _11.png
# output/a close up of a person with pink and blue hair with snow on her face and a street sign in the background with trees and snow on the ground_20 _0.png
# Renaming output/a close up of a person with pink and blue hair with snow on her face and a street sign in the background with trees and snow on the ground_20 _0.png to output/a close up of a kori page with pink and blue hair with snow on her face and a street sign in the background with trees and snow on the ground_20 _0.png
# output/a kori page in a bikini standing on the beach with a camera in her hand and a camera in her other hand, in front of a body of water with a pier in the background_43.png
# Renaming output/a kori page in a bikini standing on the beach with a camera in her hand and a camera in her other hand, in front of a body of water with a pier in the background_43.png to output/a kori page in a bikini standing on the beach with a camera in her hand and a camera in her other hand, in front of a body of water with a pier in the background_43.png
# filename already exists, appended '_n' to output/a kori page in a bikini standing on the beach with a camera in her hand and a camera in her other hand, in front of a body of water with a pier in the background_43 _13.png
# output/a kori page with purple hair standing in front of a mirror making a peace sign with her right hand and a cat on her left side of her left hand_41.png
# Renaming output/a kori page with purple hair standing in front of a mirror making a peace sign with her right hand and a cat on her left side of her left hand_41.png to output/a kori page with purple hair standing in front of a mirror making a peace sign with her right hand and a cat on her left side of her left hand_41.png
# filename already exists, appended '_n' to output/a kori page with purple hair standing in front of a mirror making a peace sign with her right hand and a cat on her left side of her left hand_41 _14.png
# output/a kori page holding a fish in her hands while standing next to a body of water with trees on both sides of her face and a body of water behind her_45.png
# Renaming output/a kori page holding a fish in her hands while standing next to a body of water with trees on both sides of her face and a body of water behind her_45.png to output/a kori page holding a fish in her hands while standing next to a body of water with trees on both sides of her face and a body of water behind her_45.png
# filename already exists, appended '_n' to output/a kori page holding a fish in her hands while standing next to a body of water with trees on both sides of her face and a body of water behind her_45 _15.png
# output/a kori page with dreadlocks taking a selfie in front of a mountain with a pine tree in the foreground and a blue sky with clouds in the background_37.png
# Renaming output/a kori page with dreadlocks taking a selfie in front of a mountain with a pine tree in the foreground and a blue sky with clouds in the background_37.png to output/a kori page with dreadlocks taking a selfie in front of a mountain with a pine tree in the foreground and a blue sky with clouds in the background_37.png
# filename already exists, appended '_n' to output/a kori page with dreadlocks taking a selfie in front of a mountain with a pine tree in the foreground and a blue sky with clouds in the background_37 _16.png
# output/a young kori page sitting on the ground with her hand under her chin, wearing a yellow beanie and a blue t - shirt with red and black shorts_40.png
# Renaming output/a young kori page sitting on the ground with her hand under her chin, wearing a yellow beanie and a blue t - shirt with red and black shorts_40.png to output/a young kori page sitting on the ground with her hand under her chin, wearing a yellow beanie and a blue t - shirt with red and black shorts_40.png
# filename already exists, appended '_n' to output/a young kori page sitting on the ground with her hand under her chin, wearing a yellow beanie and a blue t - shirt with red and black shorts_40 _17.png
# output/a kori page in a bikini standing next to a fence and looking at a body of water that has blue and green algae growing on the bottom of the water_38.png
# Renaming output/a kori page in a bikini standing next to a fence and looking at a body of water that has blue and green algae growing on the bottom of the water_38.png to output/a kori page in a bikini standing next to a fence and looking at a body of water that has blue and green algae growing on the bottom of the water_38.png
# filename already exists, appended '_n' to output/a kori page in a bikini standing next to a fence and looking at a body of water that has blue and green algae growing on the bottom of the water_38 _18.png
# output/two young women sitting next to each other in front of a sign that says love is in the air and a heart is on the top of the sign_7 _21.png
# Renaming output/two young women sitting next to each other in front of a sign that says love is in the air and a heart is on the top of the sign_7 _21.png to output/two young women sitting next to each other in front of a sign that says love is in the air and a heart is on the top of the sign_7 _21.png
# filename already exists, appended '_n' to output/two young women sitting next to each other in front of a sign that says love is in the air and a heart is on the top of the sign_7 _21 _19.png
# output/a close up of a person with pink hair holding a camera and wearing a purple tank top and holding a camera in one hand and a pink frisbee in the other hand_39 _36.png
# Renaming output/a close up of a person with pink hair holding a camera and wearing a purple tank top and holding a camera in one hand and a pink frisbee in the other hand_39 _36.png to output/a close up of a kori page with pink hair holding a camera and wearing a purple tank top and holding a camera in one hand and a pink frisbee in the other hand_39 _36.png
# output/a kori page in a bikini standing next to a wooden fence in front of a body of water with trees and bushes on both sides of the fence is posing for a picture_24.png
# Renaming output/a kori page in a bikini standing next to a wooden fence in front of a body of water with trees and bushes on both sides of the fence is posing for a picture_24.png to output/a kori page in a bikini standing next to a wooden fence in front of a body of water with trees and bushes on both sides of the fence is posing for a picture_24.png
# filename already exists, appended '_n' to output/a kori page in a bikini standing next to a wooden fence in front of a body of water with trees and bushes on both sides of the fence is posing for a picture_24 _21.png
# output/a girl in a green shirt and a yellow hat is playing with a frisbee in the grass near a body of water with trees in the background_12 _43.png
# Renaming output/a girl in a green shirt and a yellow hat is playing with a frisbee in the grass near a body of water with trees in the background_12 _43.png to output/a girl in a green shirt and a yellow hat is playing with a frisbee in the grass near a body of water with trees in the background_12 _43.png
# filename already exists, appended '_n' to output/a girl in a green shirt and a yellow hat is playing with a frisbee in the grass near a body of water with trees in the background_12 _43 _22.png
# output/a girl with pink hair wearing a white graduation cap and gown with a tassel and a tassel hanging off of it's side of her head_34 _20.png
# Renaming output/a girl with pink hair wearing a white graduation cap and gown with a tassel and a tassel hanging off of it's side of her head_34 _20.png to output/a girl with pink hair wearing a white graduation cap and gown with a tassel and a tassel hanging off of it's side of her head_34 _20.png
# filename already exists, appended '_n' to output/a girl with pink hair wearing a white graduation cap and gown with a tassel and a tassel hanging off of it's side of her head_34 _20 _23.png
# output/a kori page standing in front of a mountain with a cell phone in her hand and a cell phone in her other hand, with a mountain in the background_18.png
# Renaming output/a kori page standing in front of a mountain with a cell phone in her hand and a cell phone in her other hand, with a mountain in the background_18.png to output/a kori page standing in front of a mountain with a cell phone in her hand and a cell phone in her other hand, with a mountain in the background_18.png
# filename already exists, appended '_n' to output/a kori page standing in front of a mountain with a cell phone in her hand and a cell phone in her other hand, with a mountain in the background_18 _24.png
# output/a girl with pink hair sitting in the back seat of a car with pink hair and piercings on her nose and behind the wheel of a car seat_3 _9.png
# Renaming output/a girl with pink hair sitting in the back seat of a car with pink hair and piercings on her nose and behind the wheel of a car seat_3 _9.png to output/a girl with pink hair sitting in the back seat of a car with pink hair and piercings on her nose and behind the wheel of a car seat_3 _9.png
# filename already exists, appended '_n' to output/a girl with pink hair sitting in the back seat of a car with pink hair and piercings on her nose and behind the wheel of a car seat_3 _9 _25.png
# output/a girl with pink hair is posing for a picture in a wooded area with leaves on the ground and a lot of trees with yellow and orange leaves on the ground_26 _29.png
# Renaming output/a girl with pink hair is posing for a picture in a wooded area with leaves on the ground and a lot of trees with yellow and orange leaves on the ground_26 _29.png to output/a girl with pink hair is posing for a picture in a wooded area with leaves on the ground and a lot of trees with yellow and orange leaves on the ground_26 _29.png
# filename already exists, appended '_n' to output/a girl with pink hair is posing for a picture in a wooded area with leaves on the ground and a lot of trees with yellow and orange leaves on the ground_26 _29 _26.png
# output/a collage of photos of a kori page, a child, and a kori page sitting on a bench in front of a red truck with a sunset in the background_30.png
# Renaming output/a collage of photos of a kori page, a child, and a kori page sitting on a bench in front of a red truck with a sunset in the background_30.png to output/a collage of photos of a kori page, a child, and a kori page sitting on a bench in front of a red truck with a sunset in the background_30.png
# filename already exists, appended '_n' to output/a collage of photos of a kori page, a child, and a kori page sitting on a bench in front of a red truck with a sunset in the background_30 _27.png
# output/a girl with pink hair standing in front of a field of sunflowers and smiling at the camera with her long pink hair in front of her face_9 _15.png
# Renaming output/a girl with pink hair standing in front of a field of sunflowers and smiling at the camera with her long pink hair in front of her face_9 _15.png to output/a girl with pink hair standing in front of a field of sunflowers and smiling at the camera with her long pink hair in front of her face_9 _15.png
# filename already exists, appended '_n' to output/a girl with pink hair standing in front of a field of sunflowers and smiling at the camera with her long pink hair in front of her face_9 _15 _28.png
# ...
# output/a kori page standing in front of a red door with her hand on the side of the door and her hand on the side of the door of the door_35 _6.png
# Renaming output/a kori page standing in front of a red door with her hand on the side of the door and her hand on the side of the door of the door_35 _6.png to output/kori page standing in front of a red door with her hand on the side of the door and her hand on the side of the door of the door_35 _6.png
# output/a close up of a kori page with pink and blue hair with snow on her face and a street sign in the background with trees and snow on the ground_20 _0.png
# Renaming output/a close up of a kori page with pink and blue hair with snow on her face and a street sign in the background with trees and snow on the ground_20 _0.png to output/a close up of kori page with pink and blue hair with snow on her face and a street sign in the background with trees and snow on the ground_20 _0.png
# output/a young kori page sitting on the ground with her hand under her chin, wearing a yellow beanie and a blue t - shirt with red and black shorts_40 _17.png
# Renaming output/a young kori page sitting on the ground with her hand under her chin, wearing a yellow beanie and a blue t - shirt with red and black shorts_40 _17.png to output/a young kori page sitting on the ground with her hand under her chin, wearing a yellow beanie and a blue t - shirt with red and black shorts_40 _17.png
# filename already exists, appended '_n' to output/a young kori page sitting on the ground with her hand under her chin, wearing a yellow beanie and a blue t - shirt with red and black shorts_40 _17 _23.png
# output/a kori page with pink hair in a black bikini standing in the water under a pier with her hands in the air and her right hand up in the air_31 _10.png
# Renaming output/a kori page with pink hair in a black bikini standing in the water under a pier with her hands in the air and her right hand up in the air_31 _10.png to output/kori page with pink hair in a black bikini standing in the water under a pier with her hands in the air and her right hand up in the air_31 _10.png
# output/a kori page with dreadlocks taking a selfie in front of a mountain with a pine tree in the foreground and a blue sky with clouds in the background_37 _16.png
# Renaming output/a kori page with dreadlocks taking a selfie in front of a mountain with a pine tree in the foreground and a blue sky with clouds in the background_37 _16.png to output/kori page with dreadlocks taking a selfie in front of a mountain with a pine tree in the foreground and a blue sky with clouds in the background_37 _16.png
# output/a girl in a green shirt and a yellow hat is playing with a frisbee in the grass near a body of water with trees in the background_12 _43 _22.png
# Renaming output/a girl in a green shirt and a yellow hat is playing with a frisbee in the grass near a body of water with trees in the background_12 _43 _22.png to output/a girl in a green shirt and a yellow hat is playing with a frisbee in the grass near a body of water with trees in the background_12 _43 _22.png
# filename already exists, appended '_n' to output/a girl in a green shirt and a yellow hat is playing with a frisbee in the grass near a body of water with trees in the background_12 _43 _22 _26.png
# output/a girl with pink hair wearing a white graduation cap and gown with a tassel and a tassel hanging off of it's side of her head_34 _20 _23.png
# Renaming output/a girl with pink hair wearing a white graduation cap and gown with a tassel and a tassel hanging off of it's side of her head_34 _20 _23.png to output/a girl with pink hair wearing a white graduation cap and gown with a tassel and a tassel hanging off of it's side of her head_34 _20 _23.png
# filename already exists, appended '_n' to output/a girl with pink hair wearing a white graduation cap and gown with a tassel and a tassel hanging off of it's side of her head_34 _20 _23 _27.png
# output/a kori page holding a fish in her hands while standing next to a body of water with trees on both sides of her face and a body of water behind her_45 _15.png
# Renaming output/a kori page holding a fish in her hands while standing next to a body of water with trees on both sides of her face and a body of water behind her_45 _15.png to output/kori page holding a fish in her hands while standing next to a body of water with trees on both sides of her face and a body of water behind her_45 _15.png
# output/a close up of a kori page with pink hair holding a camera and wearing a purple tank top and holding a camera in one hand and a pink frisbee in the other hand_39 _36.png
# Renaming output/a close up of a kori page with pink hair holding a camera and wearing a purple tank top and holding a camera in one hand and a pink frisbee in the other hand_39 _36.png to output/a close up of kori page with pink hair holding a camera and wearing a purple tank top and holding a camera in one hand and a pink frisbee in the other hand_39 _36.png
# output/a kori page with blue hair and piercings standing in front of a door with a smile on her face and wearing a red tank top with a black band around her neck_33 _39.png
# Renaming output/a kori page with blue hair and piercings standing in front of a door with a smile on her face and wearing a red tank top with a black band around her neck_33 _39.png to output/kori page with blue hair and piercings standing in front of a door with a smile on her face and wearing a red tank top with a black band around her neck_33 _39.png
# output/a kori page in a bikini standing next to a body of water with an inflatable raft in the foreground and a body of water in the background_29 _35.png
# Renaming output/a kori page in a bikini standing next to a body of water with an inflatable raft in the foreground and a body of water in the background_29 _35.png to output/kori page in a bikini standing next to a body of water with an inflatable raft in the foreground and a body of water in the background_29 _35.png
# output/a young kori page with dreadlocks standing in front of a lush green forest, smiling at the camera, wearing a blue jacket and white t - shirt_44 _38.png
# Renaming output/a young kori page with dreadlocks standing in front of a lush green forest, smiling at the camera, wearing a blue jacket and white t - shirt_44 _38.png to output/a young kori page with dreadlocks standing in front of a lush green forest, smiling at the camera, wearing a blue jacket and white t - shirt_44 _38.png
# filename already exists, appended '_n' to output/a young kori page with dreadlocks standing in front of a lush green forest, smiling at the camera, wearing a blue jacket and white t - shirt_44 _38 _32.png
# output/two girls standing next to each other in front of a building with a clock on the side of the building and people sitting at tables on the other side of the street_32 _6 _46.png
# Renaming output/two girls standing next to each other in front of a building with a clock on the side of the building and people sitting at tables on the other side of the street_32 _6 _46.png to output/two girls standing next to each other in front of a building with a clock on the side of the building and people sitting at tables on the other side of the street_32 _6 _46.png
# filename already exists, appended '_n' to output/two girls standing next to each other in front of a building with a clock on the side of the building and people sitting at tables on the other side of the street_32 _6 _46 _33.png
# output/a kori page with blue hair sitting on a chair with tattoos on her legs and a tattoo on her lower half of the leg of the kori page's leg_21 _41.png
# Renaming output/a kori page with blue hair sitting on a chair with tattoos on her legs and a tattoo on her lower half of the leg of the kori page's leg_21 _41.png to output/kori page with blue hair sitting on a chair with tattoos on her legs and a tattoo on her lower half of the leg of the kori page's leg_21 _41.png
# output/a kori page sitting next to a small child on a bench in front of a train with the words happy birthday written on the back of the kori page's shirt_11 _7.png
# Renaming output/a kori page sitting next to a small child on a bench in front of a train with the words happy birthday written on the back of the kori page's shirt_11 _7.png to output/kori page sitting next to a small child on a bench in front of a train with the words happy birthday written on the back of the kori page's shirt_11 _7.png
# output/a kori page in a red bikini standing in a room with a tattoo on her right arm and a tattoo on her left arm, and a tattoo on her left arm_42 _30.png
# Renaming output/a kori page in a red bikini standing in a room with a tattoo on her right arm and a tattoo on her left arm, and a tattoo on her left arm_42 _30.png to output/kori page in a red bikini standing in a room with a tattoo on her right arm and a tattoo on her left arm, and a tattoo on her left arm_42 _30.png
# output/a kori page in a bikini standing on the beach with a camera in her hand and a camera in her other hand, in front of a body of water with a pier in the background_43 _13.png
# Renaming output/a kori page in a bikini standing on the beach with a camera in her hand and a camera in her other hand, in front of a body of water with a pier in the background_43 _13.png to output/kori page in a bikini standing on the beach with a camera in her hand and a camera in her other hand, in front of a body of water with a pier in the background_43 _13.png
# output/a kori page with pink hair and a black shirt is standing in front of a tree and a man with pink hair is wearing a black shirt and a black t - shirt_15 _40.png
# Renaming output/a kori page with pink hair and a black shirt is standing in front of a tree and a man with pink hair is wearing a black shirt and a black t - shirt_15 _40.png to output/kori page with pink hair and a black shirt is standing in front of a tree and a man with pink hair is wearing a black shirt and a black t - shirt_15 _40.png
# output/a kori page in a bikini standing next to a wooden fence in front of a body of water with trees and bushes on both sides of the fence is posing for a picture_24 _21.png
# Renaming output/a kori page in a bikini standing next to a wooden fence in front of a body of water with trees and bushes on both sides of the fence is posing for a picture_24 _21.png to output/kori page in a bikini standing next to a wooden fence in front of a body of water with trees and bushes on both sides of the fence is posing for a picture_24 _21.png
# output/a girl with blue and purple hair standing next to a girl with pink and blue hair and a girl with blue and purple hair standing next to each other_22 _2 _31.png
# Renaming output/a girl with blue and purple hair standing next to a girl with pink and blue hair and a girl with blue and purple hair standing next to each other_22 _2 _31.png to output/a girl with blue and purple hair standing next to a girl with pink and blue hair and a girl with blue and purple hair standing next to each other_22 _2 _31.png
# filename already exists, appended '_n' to output/a girl with blue and purple hair standing next to a girl with pink and blue hair and a girl with blue and purple hair standing next to each other_22 _2 _31 _40.png
# output/a girl with pink hair is sitting on the ground with her legs crossed and a smile on her face as she sits in a field with mountains in the background_17 _13 _44.png
# Renaming output/a girl with pink hair is sitting on the ground with her legs crossed and a smile on her face as she sits in a field with mountains in the background_17 _13 _44.png to output/a girl with pink hair is sitting on the ground with her legs crossed and a smile on her face as she sits in a field with mountains in the background_17 _13 _44.png
# filename already exists, appended '_n' to output/a girl with pink hair is sitting on the ground with her legs crossed and a smile on her face as she sits in a field with mountains in the background_17 _13 _44 _41.png
# output/a kori page in a tie - dyed shirt and fishnet stockings poses for a picture in front of a painting of a kori page wearing fishnet stockings and fishnet stockings_2 _32.png
# Renaming output/a kori page in a tie - dyed shirt and fishnet stockings poses for a picture in front of a painting of a kori page wearing fishnet stockings and fishnet stockings_2 _32.png to output/kori page in a tie - dyed shirt and fishnet stockings poses for a picture in front of a painting of kori page wearing fishnet stockings and fishnet stockings_2 _32.png
# output/a kori page in a red dress with a tattoo on her left arm and a tattoo on her right arm and a tattoo on her left arm and her left arm_1 _47.png
# Renaming output/a kori page in a red dress with a tattoo on her left arm and a tattoo on her right arm and a tattoo on her left arm and her left arm_1 _47.png to output/kori page in a red dress with a tattoo on her left arm and a tattoo on her right arm and a tattoo on her left arm and her left arm_1 _47.png
# output/a kori page with a tattoo on her arm holding a wine bottle and a wine bottle in one hand and a wine bottle in the other hand and a wine bottle in the other hand_4 _11.png
# Renaming output/a kori page with a tattoo on her arm holding a wine bottle and a wine bottle in one hand and a wine bottle in the other hand and a wine bottle in the other hand_4 _11.png to output/kori page with a tattoo on her arm holding a wine bottle and a wine bottle in one hand and a wine bottle in the other hand and a wine bottle in the other hand_4 _11.png
# output/a kori page in a red swimsuit with tattoos on her chest and chest, standing in a living room with a ceiling fan and a staircase in the background_14 _36.png
# Renaming output/a kori page in a red swimsuit with tattoos on her chest and chest, standing in a living room with a ceiling fan and a staircase in the background_14 _36.png to output/kori page in a red swimsuit with tattoos on her chest and chest, standing in a living room with a ceiling fan and a staircase in the background_14 _36.png
# output/a kori page with pink hair standing on the side of a train with her hand up to the side of the train as she stands on the side of the train_47 _4.png
# Renaming output/a kori page with pink hair standing on the side of a train with her hand up to the side of the train as she stands on the side of the train_47 _4.png to output/kori page with pink hair standing on the side of a train with her hand up to the side of the train as she stands on the side of the train_47 _4.png
# output/a girl with pink dreadlocks and a beanie smiles at the camera while standing in front of a skate park with a skateboard in the background_27 _37 _5.png
# Renaming output/a girl with pink dreadlocks and a beanie smiles at the camera while standing in front of a skate park with a skateboard in the background_27 _37 _5.png to output/a girl with pink dreadlocks and a beanie smiles at the camera while standing in front of a skate park with a skateboard in the background_27 _37 _5.png
# filename already exists, appended '_n' to output/a girl with pink dreadlocks and a beanie smiles at the camera while standing in front of a skate park with a skateboard in the background_27 _37 _5 _47.png
# output/two young women sitting next to each other in front of a sign that says love is in the air and a heart is on the top of the sign_7 _21 _19.png
# Renaming output/two young women sitting next to each other in front of a sign that says love is in the air and a heart is on the top of the sign_7 _21 _19.png to output/two young women sitting next to each other in front of a sign that says love is in the air and a heart is on the top of the sign_7 _21 _19.png
# filename already exists, appended '_n' to output/two young women sitting next to each other in front of a sign that says love is in the air and a heart is on the top of the sign_7 _21 _19 _48.png
# /content/EveryDream/scripts/filename_replace.py executed in 0.05 seconds.

# %% [markdown]
# # Laion Downloader
#
# * --laion_dir: directory with laion parquet files, default is ./laion
#
# * --search_text: csv of words with AND logic, ex \"photo,man,dog\"
#
# * --out_dir: directory to download files to, ive defaulted this to inputs so they can be captioned
#
# * --log_dir: directory for logs, if ommitted will not log, logs may be large!
#
# * --column:column to search for matches, defaults is 'TEXT', but you could use 'URL' if you wanted",
#
# * --limit: max number of matching images to download, warning: may be slightly imprecise due to concurrency and http errors, defaults is 100
#
# * --min_hw: min height AND width of image to download, default is 512
#
# * --force: forces a full download of all images, even if no search is provided, USE CAUTION!
#
# * --parquet_skip: skips the first n parquet files on disk, useful to resume
#
# * --verbose: additional logging of URL and TEXT
#
# * --test: skips downloading, for checking filters, use with "--verbose"

# %%
# !python scripts/download_laion.py \
--laion_dir ./laion \
--search_text "photo,man,dog" \
#--out_dir input \
#--log_dir logs \
#--column TEXT \
#--limit 100 \
#--min_hw 512 \
#--force False \
#--parquet_skip 0 \
#--Verbose False \
#--test not \

# %% [markdown]
# Here we can take our now captioned images and replace generic terms with our subjects
#
# * --find: will search for a word in this case man
#
# * --replace: will replace our found word with in this case bob smith
#
# * --append_only: this will allow us to add a tag at he end

# %%
# !python scripts/filename_replace.py \
--img_dir output \
--find "a girl" \
--replace "kori page"
# Out:
# output/kori page in a bikini standing next to a body of water with an inflatable raft in the foreground and a body of water in the background_29 _35.png
# Renaming output/kori page in a bikini standing next to a body of water with an inflatable raft in the foreground and a body of water in the background_29 _35.png to output/kori page in a bikini standing next to a body of water with an inflatable raft in the foreground and a body of water in the background_29 _35.png
# filename already exists, appended '_n' to output/kori page in a bikini standing next to a body of water with an inflatable raft in the foreground and a body of water in the background_29 _35 _0.png
# output/a close up of kori page with dreadlocks on her head and a tattoo on her upper half of the body and behind her is a blue tank top_16 _7.png
# Renaming output/a close up of kori page with dreadlocks on her head and a tattoo on her upper half of the body and behind her is a blue tank top_16 _7.png to output/a close up of kori page with dreadlocks on her head and a tattoo on her upper half of the body and behind her is a blue tank top_16 _7.png
# filename already exists, appended '_n' to output/a close up of kori page with dreadlocks on her head and a tattoo on her upper half of the body and behind her is a blue tank top_16 _7 _1.png
# output/kori page with red hair standing in front of a bridge with a camera in her hand and holding a camera in one hand and a camera in the other hand_0 _45.png
# Renaming output/kori page with red hair standing in front of a bridge with a camera in her hand and holding a camera in one hand and a camera in the other hand_0 _45.png to output/kori page with red hair standing in front of a bridge with a camera in her hand and holding a camera in one hand and a camera in the other hand_0 _45.png
# filename already exists, appended '_n' to output/kori page with red hair standing in front of a bridge with a camera in her hand and holding a camera in one hand and a camera in the other hand_0 _45 _2.png
# output/a young kori page with blue dreadlocks and piercings sitting on a porch with her hand on her hip and looking at the camera with a smile on her face_36 _43 _5.png
# Renaming output/a young kori page with blue dreadlocks and piercings sitting on a porch with her hand on her hip and looking at the camera with a smile on her face_36 _43 _5.png to output/a young kori page with blue dreadlocks and piercings sitting on a porch with her hand on her hip and looking at the camera with a smile on her face_36 _43 _5.png
# filename already exists, appended '_n' to output/a young kori page with blue dreadlocks and piercings sitting on a porch with her hand on her hip and looking at the camera with a smile on her face_36 _43 _5 _3.png
# output/kori page covered in mud posing for a picture in a wooded area with trees and bushes behind her, with a pink mohawk on her head and a gray tank top_25 _8.png
# Renaming output/kori page covered in mud posing for a picture in a wooded area with trees and bushes behind her, with a pink mohawk on her head and a gray tank top_25 _8.png to output/kori page covered in mud posing for a picture in a wooded area with trees and bushes behind her, with a pink mohawk on her head and a gray tank top_25 _8.png
# filename already exists, appended '_n' to output/kori page covered in mud posing for a picture in a wooded area with trees and bushes behind her, with a pink mohawk on her head and a gray tank top_25 _8 _4.png
# output/kori page in a blue bikini standing next to a body of water with a frisbee in her hand and a frisbee in her other hand_10 _0.png
# Renaming output/kori page in a blue bikini standing next to a body of water with a frisbee in her hand and a frisbee in her other hand_10 _0.png to output/kori page in a blue bikini standing next to a body of water with a frisbee in her hand and a frisbee in her other hand_10 _0.png
# filename already exists, appended '_n' to output/kori page in a blue bikini standing next to a body of water with a frisbee in her hand and a frisbee in her other hand_10 _0 _5.png
# output/kori page with pink hair standing on the side of a train with her hand up to the side of the train as she stands on the side of the train_47 _4.png
# Renaming output/kori page with pink hair standing on the side of a train with her hand up to the side of the train as she stands on the side of the train_47 _4.png to output/kori page with pink hair standing on the side of a train with her hand up to the side of the train as she stands on the side of the train_47 _4.png
# filename already exists, appended '_n' to output/kori page with pink hair standing on the side of a train with her hand up to the side of the train as she stands on the side of the train_47 _4 _6.png
# output/a girl with pink hair is posing for a picture in a wooded area with leaves on the ground and a lot of trees with yellow and orange leaves on the ground_26 _29 _26 _1.png
# Renaming output/a girl with pink hair is posing for a picture in a wooded area with leaves on the ground and a lot of trees with yellow and orange leaves on the ground_26 _29 _26 _1.png to output/kori page with pink hair is posing for a picture in a wooded area with leaves on the ground and a lot of trees with yellow and orange leaves on the ground_26 _29 _26 _1.png
# output/a girl with pink hair standing in front of a field of sunflowers and smiling at the camera with her long pink hair in front of her face_9 _15 _28 _15.png
# Renaming output/a girl with pink hair standing in front of a field of sunflowers and smiling at the camera with her long pink hair in front of her face_9 _15 _28 _15.png to output/kori page with pink hair standing in front of a field of sunflowers and smiling at the camera with her long pink hair in front of her face_9 _15 _28 _15.png
# output/a close up of kori page with pink hair holding a camera and wearing a purple tank top and holding a camera in one hand and a pink frisbee in the other hand_39 _36.png
# Renaming output/a close up of kori page with pink hair holding a camera and wearing a purple tank top and holding a camera in one hand and a pink frisbee in the other hand_39 _36.png to output/a close up of kori page with pink hair holding a camera and wearing a purple tank top and holding a camera in one hand and a pink frisbee in the other hand_39 _36.png
# filename already exists, appended '_n' to output/a close up of kori page with pink hair holding a camera and wearing a purple tank top and holding a camera in one hand and a pink frisbee in the other hand_39 _36 _9.png
# output/kori page standing in front of a mountain with a cell phone in her hand and a cell phone in her other hand, with a mountain in the background_18 _24.png
# Renaming output/kori page standing in front of a mountain with a cell phone in her hand and a cell phone in her other hand, with a mountain in the background_18 _24.png to output/kori page standing in front of a mountain with a cell phone in her hand and a cell phone in her other hand, with a mountain in the background_18 _24.png
# filename already exists, appended '_n' to output/kori page standing in front of a mountain with a cell phone in her hand and a cell phone in her other hand, with a mountain in the background_18 _24 _10.png
# output/kori page standing on top of a large rock in the middle of a forest on top of a large rock in the foreground is a fence and trees in the background_46 _1.png
# Renaming output/kori page standing on top of a large rock in the middle of a forest on top of a large rock in the foreground is a fence and trees in the background_46 _1.png to output/kori page standing on top of a large rock in the middle of a forest on top of a large rock in the foreground is a fence and trees in the background_46 _1.png
# filename already exists, appended '_n' to output/kori page standing on top of a large rock in the middle of a forest on top of a large rock in the foreground is a fence and trees in the background_46 _1 _11.png
# output/a girl in a green shirt and a yellow hat is playing with a frisbee in the grass near a body of water with trees in the background_12 _43 _22 _26.png
# Renaming output/a girl in a green shirt and a yellow hat is playing with a frisbee in the grass near a body of water with trees in the background_12 _43 _22 _26.png to output/kori page in a green shirt and a yellow hat is playing with a frisbee in the grass near a body of water with trees in the background_12 _43 _22 _26.png
# output/kori page with blue hair and piercings standing in front of a door with a smile on her face and wearing a red tank top with a black band around her neck_33 _39.png
# Renaming output/kori page with blue hair and piercings standing in front of a door with a smile on her face and wearing a red tank top with a black band around her neck_33 _39.png to output/kori page with blue hair and piercings standing in front of a door with a smile on her face and wearing a red tank top with a black band around her neck_33 _39.png
# filename already exists, appended '_n' to output/kori page with blue hair and piercings standing in front of a door with a smile on her face and wearing a red tank top with a black band around her neck_33 _39 _13.png
# output/kori page standing in front of a red door with her hand on the side of the door and her hand on the side of the door of the door_35 _6.png
# Renaming output/kori page standing in front of a red door with her hand on the side of the door and her hand on the side of the door of the door_35 _6.png to output/kori page standing in front of a red door with her hand on the side of the door and her hand on the side of the door of the door_35 _6.png
# filename already exists, appended '_n' to output/kori page standing in front of a red door with her hand on the side of the door and her hand on the side of the door of the door_35 _6 _14.png
# output/two young women sitting next to each other in front of a sign that says love is in the air and a heart is on the top of the sign_7 _21 _19 _48.png
# Renaming output/two young women sitting next to each other in front of a sign that says love is in the air and a heart is on the top of the sign_7 _21 _19 _48.png to output/two young women sitting next to each other in front of a sign that says love is in the air and a heart is on the top of the sign_7 _21 _19 _48.png
# filename already exists, appended '_n' to output/two young women sitting next to each other in front of a sign that says love is in the air and a heart is on the top of the sign_7 _21 _19 _48 _15.png
# output/kori page with dreadlocks taking a selfie in front of a mountain with a pine tree in the foreground and a blue sky with clouds in the background_37 _16.png
# Renaming output/kori page with dreadlocks taking a selfie in front of a mountain with a pine tree in the foreground and a blue sky with clouds in the background_37 _16.png to output/kori page with dreadlocks taking a selfie in front of a mountain with a pine tree in the foreground and a blue sky with clouds in the background_37 _16.png
# filename already exists, appended '_n' to output/kori page with dreadlocks taking a selfie in front of a mountain with a pine tree in the foreground and a blue sky with clouds in the background_37 _16 _16.png
# output/kori page in a bikini standing on the beach with a camera in her hand and a camera in her other hand, in front of a body of water with a pier in the background_43 _13.png
# Renaming output/kori page in a bikini standing on the beach with a camera in her hand and a camera in her other hand, in front of a body of water with a pier in the background_43 _13.png to output/kori page in a bikini standing on the beach with a camera in her hand and a camera in her other hand, in front of a body of water with a pier in the background_43 _13.png
# filename already exists, appended '_n' to output/kori page in a bikini standing on the beach with a camera in her hand and a camera in her other hand, in front of a body of water with a pier in the background_43 _13 _17.png
# output/kori page with blue hair sitting on a chair with tattoos on her legs and a tattoo on her lower half of the leg of the kori page's leg_21 _41.png
# Renaming output/kori page with blue hair sitting on a chair with tattoos on her legs and a tattoo on her lower half of the leg of the kori page's leg_21 _41.png to output/kori page with blue hair sitting on a chair with tattoos on her legs and a tattoo on her lower half of the leg of the kori page's leg_21 _41.png
# filename already exists, appended '_n' to output/kori page with blue hair sitting on a chair with tattoos on her legs and a tattoo on her lower half of the leg of the kori page's leg_21 _41 _18.png
# output/kori page in a bikini standing next to a wooden fence in front of a body of water with trees and bushes on both sides of the fence is posing for a picture_24 _21.png
# Renaming output/kori page in a bikini standing next to a wooden fence in front of a body of water with trees and bushes on both sides of the fence is posing for a picture_24 _21.png to output/kori page in a bikini standing next to a wooden fence in front of a body of water with trees and bushes on both sides of the fence is posing for a picture_24 _21.png
# filename already exists, appended '_n' to output/kori page in a bikini standing next to a wooden fence in front of a body of water with trees and bushes on both sides of the fence is posing for a picture_24 _21 _19.png
# output/kori page with a tattoo on her arm holding a wine bottle and a wine bottle in one hand and a wine bottle in the other hand and a wine bottle in the other hand_4 _11.png
# Renaming output/kori page with a tattoo on her arm holding a wine bottle and a wine bottle in one hand and a wine bottle in the other hand and a wine bottle in the other hand_4 _11.png to output/kori page with a tattoo on her arm holding a wine bottle and a wine bottle in one hand and a wine bottle in the other hand and a wine bottle in the other hand_4 _11.png
# filename already exists, appended '_n' to output/kori page with a tattoo on her arm holding a wine bottle and a wine bottle in one hand and a wine bottle in the other hand and a wine bottle in the other hand_4 _11 _20.png
# output/kori page in a tie - dyed shirt and fishnet stockings poses for a picture in front of a painting of kori page wearing fishnet stockings and fishnet stockings_2 _32.png
# Renaming output/kori page in a tie - dyed shirt and fishnet stockings poses for a picture in front of a painting of kori page wearing fishnet stockings and fishnet stockings_2 _32.png to output/kori page in a tie - dyed shirt and fishnet stockings poses for a picture in front of a painting of kori page wearing fishnet stockings and fishnet stockings_2 _32.png
# filename already exists, appended '_n' to output/kori page in a tie - dyed shirt and fishnet stockings poses for a picture in front of a painting of kori page wearing fishnet stockings and fishnet stockings_2 _32 _21.png
# output/kori page with pink hair standing on a dirt path next to a body of water with a bottle of water in her hand and a cup in her other hand_23 _34.png
# Renaming output/kori page with pink hair standing on a dirt path next to a body of water with a bottle of water in her hand and a cup in her other hand_23 _34.png to output/kori page with pink hair standing on a dirt path next to a body of water with a bottle of water in her hand and a cup in her other hand_23 _34.png
# filename already exists, appended '_n' to output/kori page with pink hair standing on a dirt path next to a body of water with a bottle of water in her hand and a cup in her other hand_23 _34 _22.png
# output/a close up of kori page with pink and blue hair with snow on her face and a street sign in the background with trees and snow on the ground_20 _0.png
# Renaming output/a close up of kori page with pink and blue hair with snow on her face and a street sign in the background with trees and snow on the ground_20 _0.png to output/a close up of kori page with pink and blue hair with snow on her face and a street sign in the background with trees and snow on the ground_20 _0.png
# filename already exists, appended '_n' to output/a close up of kori page with pink and blue hair with snow on her face and a street sign in the background with trees and snow on the ground_20 _0 _23.png
# output/kori page sitting in the back seat of a car with a cell phone in her hand and a cell phone in her other hand as well as well as she smiles_5 _29.png
# Renaming output/kori page sitting in the back seat of a car with a cell phone in her hand and a cell phone in her other hand as well as well as she smiles_5 _29.png to output/kori page sitting in the back seat of a car with a cell phone in her hand and a cell phone in her other hand as well as well as she smiles_5 _29.png
# filename already exists, appended '_n' to output/kori page sitting in the back seat of a car with a cell phone in her hand and a cell phone in her other hand as well as well as she smiles_5 _29 _24.png
# output/kori page standing on a beach with a palm tree in the foreground and a cloudy sky in the background, with a palm tree in the foreground_6 _37.jpg
# Renaming output/kori page standing on a beach with a palm tree in the foreground and a cloudy sky in the background, with a palm tree in the foreground_6 _37.jpg to output/kori page standing on a beach with a palm tree in the foreground and a cloudy sky in the background, with a palm tree in the foreground_6 _37.jpg
# filename already exists, appended '_n' to output/kori page standing on a beach with a palm tree in the foreground and a cloudy sky in the background, with a palm tree in the foreground_6 _37 _25.jpg
# output/a girl with pink dreadlocks and a beanie smiles at the camera while standing in front of a skate park with a skateboard in the background_27 _37 _5 _47.png
# Renaming output/a girl with pink dreadlocks and a beanie smiles at the camera while standing in front of a skate park with a skateboard in the background_27 _37 _5 _47.png to output/kori page with pink dreadlocks and a beanie smiles at the camera while standing in front of a skate park with a skateboard in the background_27 _37 _5 _47.png
# output/a collage of photos of kori page, a child, and kori page sitting on a bench in front of a red truck with a sunset in the background_30 _27.png
# Renaming output/a collage of photos of kori page, a child, and kori page sitting on a bench in front of a red truck with a sunset in the background_30 _27.png to output/a collage of photos of kori page, a child, and kori page sitting on a bench in front of a red truck with a sunset in the background_30 _27.png
# filename already exists, appended '_n' to output/a collage of photos of kori page, a child, and kori page sitting on a bench in front of a red truck with a sunset in the background_30 _27 _27.png
# output/kori page in a bikini standing next to a fence and looking at a body of water that has blue and green algae growing on the bottom of the water_38 _18.png
# Renaming output/kori page in a bikini standing next to a fence and looking at a body of water that has blue and green algae growing on the bottom of the water_38 _18.png to output/kori page in a bikini standing next to a fence and looking at a body of water that has blue and green algae growing on the bottom of the water_38 _18.png
# filename already exists, appended '_n' to output/kori page in a bikini standing next to a fence and looking at a body of water that has blue and green algae growing on the bottom of the water_38 _18 _28.png
# output/kori page in a red bikini standing in a room with a tattoo on her right arm and a tattoo on her left arm, and a tattoo on her left arm_42 _30.png
# Renaming output/kori page in a red bikini standing in a room with a tattoo on her right arm and a tattoo on her left arm, and a tattoo on her left arm_42 _30.png to output/kori page in a red bikini standing in a room with a tattoo on her right arm and a tattoo on her left arm, and a tattoo on her left arm_42 _30.png
# filename already exists, appended '_n' to output/kori page in a red bikini standing in a room with a tattoo on her right arm and a tattoo on her left arm, and a tattoo on her left arm_42 _30 _29.png
# output/kori page in ripped jeans and a yellow beanie poses for a picture in a grassy field with a mountain in the backgrouund of the background_19 _42.png
# Renaming output/kori page in ripped jeans and a yellow beanie poses for a picture in a grassy field with a mountain in the backgrouund of the background_19 _42.png to output/kori page in ripped jeans and a yellow beanie poses for a picture in a grassy field with a mountain in the backgrouund of the background_19 _42.png
# filename already exists, appended '_n' to output/kori page in ripped jeans and a yellow beanie poses for a picture in a grassy field with a mountain in the backgrouund of the background_19 _42 _30.png
# output/kori page standing in front of a bed wearing ripped jeans and a t - shirt with an image of a cat on the front of the t - shirt_13 _9.png
# Renaming output/kori page standing in front of a bed wearing ripped jeans and a t - shirt with an image of a cat on the front of the t - shirt_13 _9.png to output/kori page standing in front of a bed wearing ripped jeans and a t - shirt with an image of a cat on the front of the t - shirt_13 _9.png
# filename already exists, appended '_n' to output/kori page standing in front of a bed wearing ripped jeans and a t - shirt with an image of a cat on the front of the t - shirt_13 _9 _31.png
# output/a girl with pink hair wearing a white graduation cap and gown with a tassel and a tassel hanging off of it's side of her head_34 _20 _23 _27.png
# Renaming output/a girl with pink hair wearing a white graduation cap and gown with a tassel and a tassel hanging off of it's side of her head_34 _20 _23 _27.png to output/kori page with pink hair wearing a white graduation cap and gown with a tassel and a tassel hanging off of it's side of her head_34 _20 _23 _27.png
# output/kori page standing in front of a body of water wearing a white tank top and ripped jeans with a tattoo on her arm and a chain around her neck_48 _48.png
# Renaming output/kori page standing in front of a body of water wearing a white tank top and ripped jeans with a tattoo on her arm and a chain around her neck_48 _48.png to output/kori page standing in front of a body of water wearing a white tank top and ripped jeans with a tattoo on her arm and a chain around her neck_48 _48.png
# filename already exists, appended '_n' to output/kori page standing in front of a body of water wearing a white tank top and ripped jeans with a tattoo on her arm and a chain around her neck_48 _48 _33.png
# output/kori page with pink hair in a black bikini standing in the water under a pier with her hands in the air and her right hand up in the air_31 _10.png
# Renaming output/kori page with pink hair in a black bikini standing in the water under a pier with her hands in the air and her right hand up in the air_31 _10.png to output/kori page with pink hair in a black bikini standing in the water under a pier with her hands in the air and her right hand up in the air_31 _10.png
# filename already exists, appended '_n' to output/kori page with pink hair in a black bikini standing in the water under a pier with her hands in the air and her right hand up in the air_31 _10 _34.png
# output/a young kori page sitting on the ground with her hand under her chin, wearing a yellow beanie and a blue t - shirt with red and black shorts_40 _17 _23.png
# Renaming output/a young kori page sitting on the ground with her hand under her chin, wearing a yellow beanie and a blue t - shirt with red and black shorts_40 _17 _23.png to output/a young kori page sitting on the ground with her hand under her chin, wearing a yellow beanie and a blue t - shirt with red and black shorts_40 _17 _23.png
# filename already exists, appended '_n' to output/a young kori page sitting on the ground with her hand under her chin, wearing a yellow beanie and a blue t - shirt with red and black shorts_40 _17 _23 _35.png
# output/a young kori page with dreadlocks standing in front of a lush green forest, smiling at the camera, wearing a blue jacket and white t - shirt_44 _38 _32.png
# Renaming output/a young kori page with dreadlocks standing in front of a lush green forest, smiling at the camera, wearing a blue jacket and white t - shirt_44 _38 _32.png to output/a young kori page with dreadlocks standing in front of a lush green forest, smiling at the camera, wearing a blue jacket and white t - shirt_44 _38 _32.png
# filename already exists, appended '_n' to output/a young kori page with dreadlocks standing in front of a lush green forest, smiling at the camera, wearing a blue jacket and white t - shirt_44 _38 _32 _36.png
# output/kori page sitting next to a small child on a bench in front of a train with the words happy birthday written on the back of the kori page's shirt_11 _7.png
# Renaming output/kori page sitting next to a small child on a bench in front of a train with the words happy birthday written on the back of the kori page's shirt_11 _7.png to output/kori page sitting next to a small child on a bench in front of a train with the words happy birthday written on the back of the kori page's shirt_11 _7.png
# filename already exists, appended '_n' to output/kori page sitting next to a small child on a bench in front of a train with the words happy birthday written on the back of the kori page's shirt_11 _7 _37.png
# output/a close up of kori page with pink hair wearing a black tank top and a bracelet with a bird on it and a flower on the side of her arm_28 _30.png
# Renaming output/a close up of kori page with pink hair wearing a black tank top and a bracelet with a bird on it and a flower on the side of her arm_28 _30.png to output/a close up of kori page with pink hair wearing a black tank top and a bracelet with a bird on it and a flower on the side of her arm_28 _30.png
# filename already exists, appended '_n' to output/a close up of kori page with pink hair wearing a black tank top and a bracelet with a bird on it and a flower on the side of her arm_28 _30 _38.png
# output/a girl with pink hair is sitting on the ground with her legs crossed and a smile on her face as she sits in a field with mountains in the background_17 _13 _44 _41.png
# Renaming output/a girl with pink hair is sitting on the ground with her legs crossed and a smile on her face as she sits in a field with mountains in the background_17 _13 _44 _41.png to output/kori page with pink hair is sitting on the ground with her legs crossed and a smile on her face as she sits in a field with mountains in the background_17 _13 _44 _41.png
# output/kori page holding a fish in her hands while standing next to a body of water with trees on both sides of her face and a body of water behind her_45 _15.png
# Renaming output/kori page holding a fish in her hands while standing next to a body of water with trees on both sides of her face and a body of water behind her_45 _15.png to output/kori page holding a fish in her hands while standing next to a body of water with trees on both sides of her face and a body of water behind her_45 _15.png
# filename already exists, appended '_n' to output/kori page holding a fish in her hands while standing next to a body of water with trees on both sides of her face and a body of water behind her_45 _15 _40.png
# output/kori page sitting on the ground next to a baby in a stroller with a pacifier in her mouth and a baby in a stroller behind her_8 _3.png
# Renaming output/kori page sitting on the ground next to a baby in a stroller with a pacifier in her mouth and a baby in a stroller behind her_8 _3.png to output/kori page sitting on the ground next to a baby in a stroller with a pacifier in her mouth and a baby in a stroller behind her_8 _3.png
# filename already exists, appended '_n' to output/kori page sitting on the ground next to a baby in a stroller with a pacifier in her mouth and a baby in a stroller behind her_8 _3 _41.png
# output/kori page with pink hair and a black shirt is standing in front of a tree and a man with pink hair is wearing a black shirt and a black t - shirt_15 _40.png
# Renaming output/kori page with pink hair and a black shirt is standing in front of a tree and a man with pink hair is wearing a black shirt and a black t - shirt_15 _40.png to output/kori page with pink hair and a black shirt is standing in front of a tree and a man with pink hair is wearing a black shirt and a black t - shirt_15 _40.png
# filename already exists, appended '_n' to output/kori page with pink hair and a black shirt is standing in front of a tree and a man with pink hair is wearing a black shirt and a black t - shirt_15 _40 _42.png
# output/a girl with pink hair sitting in the back seat of a car with pink hair and piercings on her nose and behind the wheel of a car seat_3 _9 _25 _12.png
# Renaming output/a girl with pink hair sitting in the back seat of a car with pink hair and piercings on her nose and behind the wheel of a car seat_3 _9 _25 _12.png to output/kori page with pink hair sitting in the back seat of a car with pink hair and piercings on her nose and behind the wheel of a car seat_3 _9 _25 _12.png
# output/a girl with blue and purple hair standing next to a girl with pink and blue hair and a girl with blue and purple hair standing next to each other_22 _2 _31 _40.png
# Renaming output/a girl with blue and purple hair standing next to a girl with pink and blue hair and a girl with blue and purple hair standing next to each other_22 _2 _31 _40.png to output/kori page with blue and purple hair standing next to kori page with pink and blue hair and kori page with blue and purple hair standing next to each other_22 _2 _31 _40.png
# output/kori page in a red dress with a tattoo on her left arm and a tattoo on her right arm and a tattoo on her left arm and her left arm_1 _47.png
# Renaming output/kori page in a red dress with a tattoo on her left arm and a tattoo on her right arm and a tattoo on her left arm and her left arm_1 _47.png to output/kori page in a red dress with a tattoo on her left arm and a tattoo on her right arm and a tattoo on her left arm and her left arm_1 _47.png
# filename already exists, appended '_n' to output/kori page in a red dress with a tattoo on her left arm and a tattoo on her right arm and a tattoo on her left arm and her left arm_1 _47 _45.png
# output/kori page in a red swimsuit with tattoos on her chest and chest, standing in a living room with a ceiling fan and a staircase in the background_14 _36.png
# Renaming output/kori page in a red swimsuit with tattoos on her chest and chest, standing in a living room with a ceiling fan and a staircase in the background_14 _36.png to output/kori page in a red swimsuit with tattoos on her chest and chest, standing in a living room with a ceiling fan and a staircase in the background_14 _36.png
# filename already exists, appended '_n' to output/kori page in a red swimsuit with tattoos on her chest and chest, standing in a living room with a ceiling fan and a staircase in the background_14 _36 _46.png
# output/kori page with purple hair standing in front of a mirror making a peace sign with her right hand and a cat on her left side of her left hand_41 _14.png
# Renaming output/kori page with purple hair standing in front of a mirror making a peace sign with her right hand and a cat on her left side of her left hand_41 _14.png to output/kori page with purple hair standing in front of a mirror making a peace sign with her right hand and a cat on her left side of her left hand_41 _14.png
# filename already exists, appended '_n' to output/kori page with purple hair standing in front of a mirror making a peace sign with her right hand and a cat on her left side of her left hand_41 _14 _47.png
# output/two girls standing next to each other in front of a building with a clock on the side of the building and people sitting at tables on the other side of the street_32 _6 _46 _33.png
# Renaming output/two girls standing next to each other in front of a building with a clock on the side of the building and people sitting at tables on the other side of the street_32 _6 _46 _33.png to output/two girls standing next to each other in front of a building with a clock on the side of the building and people sitting at tables on the other side of the street_32 _6 _46 _33.png
# filename already exists, appended '_n' to output/two girls standing next to each other in front of a building with a clock on the side of the building and people sitting at tables on the other side of the street_32 _6 _46 _33 _48.png
# /content/EveryDream/scripts/filename_replace.py executed in 0.06 seconds.

# %% [markdown]
# Now we can chose to create text files based on our file names, this is usefull for images with very long discriptions or tag list, windows has a limit of 256 characters, and files will not transfer correctly to a windows program if they are longer, moving these files in a zip is fine however and causes no issues

# %%
# !python scripts/createtxtfromfilename.py

# %% [markdown]
# Compress our images

# %%
# !python scripts/compress_img.py \
--img_dir output \
--out_dir output/compressed_images \
--max_mp 1.5 
#--overwrite False \
#--Quality 95  \
#--noresize False \
#--delete \

# %% [markdown]
# ## Download your DataSet from EveryDream/output
#
# If you're on a colab you can use the cell below to push your output to your Gdrive.

# %%
# !mkdir /content/drive/MyDrive/Auto_Data_sets
# !cp -r output/ /content/drive/MyDrive/Auto_Data_sets

# %% [markdown]
# ## If not on colab/gdrive, the following will zip up your files for extraction
#
# You'll still need to use your runtime's own download feature to download the zip.
#
# ![output zip](https://github.com/victorchall/EveryDream/blob/main/demo/output_zip.png?raw=1)

# %%
# !pip install patool

import patoolib

# !mkdir zip

# !zip -r zip/kori.zip output
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: patool in /usr/local/lib/python3.9/dist-packages (1.12)
# mkdir: cannot create directory ‘zip’: File exists
#   adding: output/ (stored 0%)
#   adding: output/kori page in a bikini standing on the beach with a camera in her hand and a camera in her other hand, in front of a body of water with a pier in the background_43 _13 _17.png (deflated 0%)
#   adding: output/kori page with purple hair standing in front of a mirror making a peace sign with her right hand and a cat on her left side of her left hand_41 _14 _47.png (deflated 0%)
#   adding: output/a close up of kori page with pink hair holding a camera and wearing a purple tank top and holding a camera in one hand and a pink frisbee in the other hand_39 _36 _9.png (deflated 0%)
#   adding: output/kori page in a red swimsuit with tattoos on her chest and chest, standing in a living room with a ceiling fan and a staircase in the background_14 _36 _46.png (deflated 0%)
#   adding: output/kori page in a bikini standing next to a body of water with an inflatable raft in the foreground and a body of water in the background_29 _35 _0.png (deflated 0%)
#   adding: output/kori page with pink hair sitting in the back seat of a car with pink hair and piercings on her nose and behind the wheel of a car seat_3 _9 _25 _12.png (deflated 0%)
#   adding: output/kori page in a bikini standing next to a fence and looking at a body of water that has blue and green algae growing on the bottom of the water_38 _18 _28.png (deflated 0%)
#   adding: output/kori page with pink hair standing in front of a field of sunflowers and smiling at the camera with her long pink hair in front of her face_9 _15 _28 _15.png (deflated 0%)
#   adding: output/kori page standing in front of a red door with her hand on the side of the door and her hand on the side of the door of the door_35 _6 _14.png (deflated 0%)
#   adding: output/kori page with pink hair is posing for a picture in a wooded area with leaves on the ground and a lot of trees with yellow and orange leaves on the ground_26 _29 _26 _1.png (deflated 0%)
#   adding: output/kori page with a tattoo on her arm holding a wine bottle and a wine bottle in one hand and a wine bottle in the other hand and a wine bottle in the other hand_4 _11 _20.png (deflated 0%)
#   adding: output/kori page standing in front of a mountain with a cell phone in her hand and a cell phone in her other hand, with a mountain in the background_18 _24 _10.png (deflated 0%)
#   adding: output/a close up of kori page with pink hair wearing a black tank top and a bracelet with a bird on it and a flower on the side of her arm_28 _30 _38.png (deflated 0%)
#   adding: output/kori page with pink hair is sitting on the ground with her legs crossed and a smile on her face as she sits in a field with mountains in the background_17 _13 _44 _41.png (deflated 0%)
#   adding: output/kori page with blue hair and piercings standing in front of a door with a smile on her face and wearing a red tank top with a black band around her neck_33 _39 _13.png (deflated 0%)
#   adding: output/two young women sitting next to each other in front of a sign that says love is in the air and a heart is on the top of the sign_7 _21 _19 _48 _15.png (deflated 0%)
#   adding: output/kori page with red hair standing in front of a bridge with a camera in her hand and holding a camera in one hand and a camera in the other hand_0 _45 _2.png (deflated 0%)
#   adding: output/kori page standing on a beach with a palm tree in the foreground and a cloudy sky in the background, with a palm tree in the foreground_6 _37 _25.jpg (deflated 0%)
#   adding: output/kori page standing in front of a body of water wearing a white tank top and ripped jeans with a tattoo on her arm and a chain around her neck_48 _48 _33.png (deflated 0%)
#   adding: output/kori page standing in front of a bed wearing ripped jeans and a t - shirt with an image of a cat on the front of the t - shirt_13 _9 _31.png (deflated 0%)
#   adding: output/kori page with blue and purple hair standing next to kori page with pink and blue hair and kori page with blue and purple hair standing next to each other_22 _2 _31 _40.png (deflated 0%)
#   adding: output/kori page with pink hair standing on a dirt path next to a body of water with a bottle of water in her hand and a cup in her other hand_23 _34 _22.png (deflated 1%)
#   adding: output/two girls standing next to each other in front of a building with a clock on the side of the building and people sitting at tables on the other side of the street_32 _6 _46 _33 _48.png (deflated 0%)
#   adding: output/a young kori page with blue dreadlocks and piercings sitting on a porch with her hand on her hip and looking at the camera with a smile on her face_36 _43 _5 _3.png (deflated 0%)
#   adding: output/a close up of kori page with pink and blue hair with snow on her face and a street sign in the background with trees and snow on the ground_20 _0 _23.png (deflated 0%)
#   adding: output/kori page in a green shirt and a yellow hat is playing with a frisbee in the grass near a body of water with trees in the background_12 _43 _22 _26.png (deflated 0%)
#   adding: output/kori page holding a fish in her hands while standing next to a body of water with trees on both sides of her face and a body of water behind her_45 _15 _40.png (deflated 0%)
#   adding: output/kori page with blue hair sitting on a chair with tattoos on her legs and a tattoo on her lower half of the leg of the kori page's leg_21 _41 _18.png (deflated 0%)
#   adding: output/a young kori page sitting on the ground with her hand under her chin, wearing a yellow beanie and a blue t - shirt with red and black shorts_40 _17 _23 _35.png (deflated 0%)
#   adding: output/kori page sitting in the back seat of a car with a cell phone in her hand and a cell phone in her other hand as well as well as she smiles_5 _29 _24.png (deflated 0%)
#   adding: output/kori page with pink hair wearing a white graduation cap and gown with a tassel and a tassel hanging off of it's side of her head_34 _20 _23 _27.png (deflated 0%)
#   adding: output/kori page in a red dress with a tattoo on her left arm and a tattoo on her right arm and a tattoo on her left arm and her left arm_1 _47 _45.png (deflated 0%)
#   adding: output/kori page with pink hair standing on the side of a train with her hand up to the side of the train as she stands on the side of the train_47 _4 _6.png (deflated 0%)
#   adding: output/kori page standing on top of a large rock in the middle of a forest on top of a large rock in the foreground is a fence and trees in the background_46 _1 _11.png (deflated 0%)
#   adding: output/a collage of photos of kori page, a child, and kori page sitting on a bench in front of a red truck with a sunset in the background_30 _27 _27.png (deflated 0%)
#   adding: output/kori page in ripped jeans and a yellow beanie poses for a picture in a grassy field with a mountain in the backgrouund of the background_19 _42 _30.png (deflated 0%)
#   adding: output/kori page with dreadlocks taking a selfie in front of a mountain with a pine tree in the foreground and a blue sky with clouds in the background_37 _16 _16.png (deflated 0%)
#   adding: output/kori page in a red bikini standing in a room with a tattoo on her right arm and a tattoo on her left arm, and a tattoo on her left arm_42 _30 _29.png (deflated 0%)
#   adding: output/a close up of kori page with dreadlocks on her head and a tattoo on her upper half of the body and behind her is a blue tank top_16 _7 _1.png (deflated 0%)
#   adding: output/a young kori page with dreadlocks standing in front of a lush green forest, smiling at the camera, wearing a blue jacket and white t - shirt_44 _38 _32 _36.png (deflated 0%)
#   adding: output/kori page with pink hair and a black shirt is standing in front of a tree and a man with pink hair is wearing a black shirt and a black t - shirt_15 _40 _42.png (deflated 0%)
#   adding: output/kori page with pink dreadlocks and a beanie smiles at the camera while standing in front of a skate park with a skateboard in the background_27 _37 _5 _47.png (deflated 0%)
#   adding: output/kori page covered in mud posing for a picture in a wooded area with trees and bushes behind her, with a pink mohawk on her head and a gray tank top_25 _8 _4.png (deflated 0%)
#   adding: output/kori page in a blue bikini standing next to a body of water with a frisbee in her hand and a frisbee in her other hand_10 _0 _5.png (deflated 0%)
#   adding: output/kori page in a tie - dyed shirt and fishnet stockings poses for a picture in front of a painting of kori page wearing fishnet stockings and fishnet stockings_2 _32 _21.png (deflated 0%)
#   adding: output/kori page in a bikini standing next to a wooden fence in front of a body of water with trees and bushes on both sides of the fence is posing for a picture_24 _21 _19.png (deflated 0%)
#   adding: output/kori page with pink hair in a black bikini standing in the water under a pier with her hands in the air and her right hand up in the air_31 _10 _34.png (deflated 0%)
#   adding: output/kori page sitting next to a small child on a bench in front of a train with the words happy birthday written on the back of the kori page's shirt_11 _7 _37.png (deflated 0%)
#   adding: output/kori page sitting on the ground next to a baby in a stroller with a pacifier in her mouth and a baby in a stroller behind her_8 _3 _41.png (deflated 1%)

# %%
# !rm -r /content/EveryDream/output
# !mkdir /content/EveryDream/output
# !rm -r /content/EveryDream/input
# !mkdir /content/EveryDream/input
